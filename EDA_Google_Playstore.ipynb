# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df3=pd.read_csv('googleplaystore.csv')

# %%
df3.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df3.sample(10)
# Out:
#                                         App             Category  Rating  \
# 4517                         QR Code Reader                TOOLS     4.0
# 1960                       Metal Soldiers 2                 GAME     4.4
# 147                  Free Panda Radio Music  BOOKS_AND_REFERENCE     4.5
# 5441         Scanning under clothes (prank)               FAMILY     3.7
# 8770                             Dr. Rocket                 GAME     4.0
# 6009         Izneo, Read Manga, Comics & BD               COMICS     3.3
# 3430                  Wolves Live Wallpaper      PERSONALIZATION     4.3
# 8805           NDS Emulator - For Android 6                 GAME     4.1
# 6654  Camera MX - Free Photo & Video Camera          PHOTOGRAPHY     4.3
# 9992                             ew-Magazin   NEWS_AND_MAGAZINES     NaN
#
#      Reviews                Size     Installs  Type Price Content Rating  \
# 4517  495971                2.7M  50,000,000+  Free     0       Everyone
# ...

# %%
df3.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df3["Size"].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 429k                     1
# 200k                     1
# 460k                     1
# 728k                     1
# 619k                     1
# Name: count, Length: 462, dtype: int64

# %%
df3["Size"].isnull().sum()
# Out:
# 0

# %%
df3["Installs"].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: count, dtype: int64

# %%
df3["Price"].value_counts()
# Out:
# Price
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: count, Length: 93, dtype: int64

# %%
df3["Price"].isnull().sum()
# Out:
# 0

# %%
# Remove dollar sign
df3['Price'] = df3['Price'].replace('[\$,]', '', regex=True)

# %%
df3.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df3["Type"].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
df3["Price"].value_counts()
# Out:
# Price
# 0        10040
# 0.99       148
# 2.99       129
# 1.99        73
# 4.99        72
#          ...
# 1.75         1
# 14.00        1
# 4.85         1
# 46.99        1
# 1.04         1
# Name: count, Length: 93, dtype: int64

# %%
df3["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
import warnings
warnings.filterwarnings("ignore")

# %%
df3.shape
# Out:
# (10841, 13)

# %%
# Finding the values of M in size
df3["Size"].loc[df3["Size"].str.contains("M")].value_counts().sum()
# Out:
# 8829

# %%
df3["Size"].loc[df3["Size"].str.contains("k")].value_counts().sum()
# Out:
# 316

# %%
df3["Size"].loc[df3["Size"].str.contains("Varies with device")].value_counts().sum()
# Out:
# 1695

# %%
def convert_Size(Size):
    
    if "k" in Size:
        return float(Size.replace("k", ""))*1024
    elif "M" in Size:
        return float(Size.replace("M", ""))*1024*1024
    elif "Varies with device" in Size:
        return np.nan
    return Size

# %%
df3["Size"]=df3["Size"].apply(convert_Size)

# %%
df3["Size"]
# Out:
# 0         19922944.0
# 1         14680064.0
# 2          9122611.2
# 3         26214400.0
# 4          2936012.8
# 5          5872025.6
# 6         19922944.0
# 7         30408704.0
# 8         34603008.0
# 9          3250585.6
# 10        29360128.0
# 11        12582912.0
# 12        20971520.0
# 13        22020096.0
# 14        38797312.0
# 15         2831155.2
# 16         5767168.0
# 17        17825792.0
# 18        40894464.0
# 19        32505856.0
# 20        14680064.0
# 21        12582912.0
# 22         4404019.2
# 23         7340032.0
# 24        24117248.0
# 25         6291456.0
# 26        26214400.0
# 27         6396313.6
# 28         4823449.6
# 29         4404019.2
# 30         9646899.2
# 31         5452595.2
# 32        11534336.0
# 33        11534336.0
# 34         4404019.2
# 35         9646899.2
# 36        25165824.0
# 37               NaN
# 38        11534336.0
# 39         9856614.4
# 40        15728640.0
# 41        10485760.0
# 42               NaN
# ...

# %%
df3.rename(columns={"Size": "Size_in_bytes"}, inplace=True)

# %%
df3.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews Size_in_bytes     Installs  Type Price Content Rating  \
# 0     159    19922944.0      10,000+  Free     0       Everyone
# 1     967    14680064.0     500,000+  Free     0       Everyone
# 2   87510     9122611.2   5,000,000+  Free     0       Everyone
# 3  215644    26214400.0  50,000,000+  Free     0           Teen
# 4     967     2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df3["Size_in_bytes"] = pd.to_numeric(df3["Size_in_bytes"], errors='coerce')
df3["Size_in_MB"] = df3["Size_in_bytes"].apply(lambda x: x / (1024 * 1024))

# %%
df3["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
df3["Installs"].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: count, dtype: int64

# %%
df3["Installs"].isnull().sum()
# Out:
# 0

# %%
df3["Installs"]=df3["Installs"].apply(lambda x: x.replace("+", "") if "+" in str(x) else x)

# %%
df3["Installs"]
# Out:
# 0               10,000
# 1              500,000
# 2            5,000,000
# 3           50,000,000
# 4              100,000
# 5               50,000
# 6               50,000
# 7            1,000,000
# 8            1,000,000
# 9               10,000
# 10           1,000,000
# 11           1,000,000
# 12          10,000,000
# 13             100,000
# 14             100,000
# 15               5,000
# 16             500,000
# 17              10,000
# 18           5,000,000
# 19          10,000,000
# 20             100,000
# 21             100,000
# 22             500,000
# 23             100,000
# 24              50,000
# 25              10,000
# 26             500,000
# 27             100,000
# 28              10,000
# 29             100,000
# 30             100,000
# 31              50,000
# 32             100,000
# 33             100,000
# 34              10,000
# 35             100,000
# 36             500,000
# 37           5,000,000
# 38              10,000
# 39             500,000
# ...

# %%
df3["Installs"] = df3["Installs"].apply(lambda x: int(x.replace(',', '')) if "," in str(x) else x)

# %%
df3["Installs"] = df3["Installs"].apply(lambda x: int(x) if x != 'Free' else 0)

# %%
df3["Installs"].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           907
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               16
# Name: count, dtype: int64

# %%
# Binning in install column
bins=[-1,0,10,1000,10000,100000,1000000,10000000,10000000000]
labels=["Free","Very Low","Low","Moderate","High","Very High","Extremely High","Ultra High"]
df3['Install_category']=pd.cut(df3["Installs"],bins=bins,labels=labels)

# %%
df3.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size_in_bytes  Installs  Type  Price Content Rating  \
# 0     159     19922944.0     10000  Free    0.0       Everyone
# 1     967     14680064.0    500000  Free    0.0       Everyone
# 2   87510      9122611.2   5000000  Free    0.0       Everyone
# 3  215644     26214400.0  50000000  Free    0.0           Teen
# 4     967      2936012.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df3.describe()
# Out:
#             Rating  Size_in_bytes      Installs         Price   Size_in_MB
# count  9367.000000   9.145000e+03  1.084100e+04  10841.000000  9145.000000
# mean      4.193338   2.256133e+07  1.546291e+07      1.027273    21.516165
# std       0.537431   2.368637e+07  8.502557e+07     15.948971    22.589084
# min       1.000000   8.704000e+03  0.000000e+00      0.000000     0.008301
# 25%       4.000000   5.138022e+06  1.000000e+03      0.000000     4.900000
# 50%       4.300000   1.363149e+07  1.000000e+05      0.000000    13.000000
# 75%       4.500000   3.145728e+07  5.000000e+06      0.000000    30.000000
# max      19.000000   1.048576e+08  1.000000e+09    400.000000   100.000000

# %%
df3["Price"].value_counts()
# Out:
# Price
# 0.00      10041
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
# 3.99         63
# 1.49         46
# 5.99         30
# 2.49         26
# 9.99         21
# 6.99         13
# 399.99       12
# 14.99        11
# 4.49          9
# 29.99         7
# 24.99         7
# 3.49          7
# 7.99          7
# 5.49          6
# 19.99         6
# 11.99         5
# 6.49          5
# 12.99         5
# 8.99          5
# 10.00         3
# 16.99         3
# 1.00          3
# 2.00          3
# 13.99         2
# 8.49          2
# 17.99         2
# 1.70          2
# 3.95          2
# 79.99         2
# 7.49          2
# 9.00          2
# 10.99         2
# 39.99         2
# 33.99         2
# 1.96          1
# 19.40         1
# 4.80          1
# 3.28          1
# 4.59          1
# 15.46         1
# 3.04          1
# 4.29          1
# 2.60          1
# 2.59          1
# 3.90          1
# 154.99        1
# 4.60          1
# 28.99         1
# 2.95          1
# 2.90          1
# ...

# %%
df["Price"].loc[df["Price"].str.contains("$")].value_counts().sum()
# Out:
# 10841

# %%
df["Price"].loc[df["Price"].str.contains("0") & ~df["Price"].str.contains("/$")].value_counts().sum()
# Out:
# 10223

# %%
df3["Price"] = df3["Price"].apply(lambda x: int(x.replace(',', '')) if "," in str(x) else x)

# %%
df3["Price"] = df3["Price"].apply(lambda x: float(x) if x != 'Everyone' else 0.0)

# %%
df3.describe()
# Out:
#             Rating  Size_in_bytes      Installs         Price   Size_in_MB
# count  9367.000000   9.145000e+03  1.084100e+04  10841.000000  9145.000000
# mean      4.193338   2.256133e+07  1.546291e+07      1.027273    21.516165
# std       0.537431   2.368637e+07  8.502557e+07     15.948971    22.589084
# min       1.000000   8.704000e+03  0.000000e+00      0.000000     0.008301
# 25%       4.000000   5.138022e+06  1.000000e+03      0.000000     4.900000
# 50%       4.300000   1.363149e+07  1.000000e+05      0.000000    13.000000
# 75%       4.500000   3.145728e+07  5.000000e+06      0.000000    30.000000
# max      19.000000   1.048576e+08  1.000000e+09    400.000000   100.000000

# %%
df3["Price"].max()
# Out:
# 400.0

# %%
df3["Price"].min()
# Out:
# 0.0

# %%
df3.isnull().sum().sort_values(ascending=False)
# Out:
# Size_in_bytes       1696
# Size_in_MB          1696
# Rating              1474
# Current Ver            8
# Android Ver            3
# Type                   1
# Content Rating         1
# App                    0
# Category               0
# Reviews                0
# Installs               0
# Price                  0
# Genres                 0
# Last Updated           0
# Install_category       0
# dtype: int64

# %%
df3.isnull().sum().sum()
# Out:
# 4879

# %%
# Plot missing values
plt.figure(figsize=(10,5))
sns.heatmap(df3.isnull(), cbar=False, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# Draw bar plot for missing values
plt.figure(figsize=(10,5))
missing_percentage = df3.isnull().sum()/len(df3)*100
missing_percentage.plot(kind="bar")
plt.ylabel("Percentage")
plt.xlabel("Columns")
plt.title("Percentage of Missing Values")
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values')

# %%
missing_percentage[missing_percentage<1].plot(kind="bar")
# Out:
# <Axes: >

# %%
df3.groupby("Install_category")["Rating"].describe()
# Out:
#                    count       mean       std   min   25%   50%   75%   max
# Install_category
# Free                 1.0  19.000000       NaN  19.0  19.0  19.0  19.0  19.0
# Very Low            81.0   4.637037  0.845199   1.0   4.8   5.0   5.0   5.0
# Low               1279.0   4.171149  0.825307   1.0   3.8   4.4   4.8   5.0
# Moderate          1442.0   4.035160  0.604533   1.4   3.8   4.2   4.5   5.0
# High              1617.0   4.093197  0.505468   1.6   3.9   4.2   4.5   4.9
# Very High         2115.0   4.207470  0.376423   1.8   4.0   4.3   4.5   4.9
# Extremely High    2004.0   4.287076  0.294902   2.0   4.1   4.3   4.5   4.9
# Ultra High         828.0   4.374396  0.193726   3.1   4.3   4.4   4.5   4.8

# %%
# Fill missing values of rating column with mean of respective install_category 
df3["Rating"] = df3.groupby("Install_category")["Rating"].transform(lambda x: x.fillna(x.mean()))

# %%
df3["Rating"].isnull().sum()
# Out:
# 0

# %%
df3["Reviews"] = pd.to_numeric(df3["Reviews"], errors='coerce')
plt.figure(figsize=(10,5))
sns.boxplot(x="Install_category", y=np.log10(df3["Reviews"]), data=df3)
# Out:
# <Axes: xlabel='Install_category', ylabel='Reviews'>

# %%
df3["App"].duplicated().sum()
# Out:
# 1181

# %%
for col in df3:
    print(col, df3[col].duplicated().sum())
# Out:
# App 1181
# Category 10807
# Rating 10796
# Reviews 4839
# Size_in_bytes 10381
# Installs 10821
# Type 10837
# Price 10749
# Content Rating 10834
# Genres 10721
# Last Updated 9463
# Current Ver 8008
# Android Ver 10807
# Size_in_MB 10381
# Install_category 10833

# %%
df3[df3["App"].duplicated(keep=False)].sort_values("App")
# Out:
#                                                      App             Category  \
# 1393                               10 Best Foods for You   HEALTH_AND_FITNESS
# 1407                               10 Best Foods for You   HEALTH_AND_FITNESS
# 2543                          1800 Contacts - Lens Store              MEDICAL
# 2322                          1800 Contacts - Lens Store              MEDICAL
# 2385                          2017 EMRA Antibiotic Guide              MEDICAL
# 2256                          2017 EMRA Antibiotic Guide              MEDICAL
# 1337                        21-Day Meditation Experience   HEALTH_AND_FITNESS
# 1434                        21-Day Meditation Experience   HEALTH_AND_FITNESS
# 3083                             365Scores - Live Scores               SPORTS
# 5415                             365Scores - Live Scores               SPORTS
# 7035                              420 BZ Budeze Delivery              MEDICAL
# ...

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.shape
# Out:
# (10358, 15)

# %%
df3["Category"].value_counts().head(10)
# Out:
# Category
# FAMILY             1943
# GAME               1121
# TOOLS               843
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     388
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: count, dtype: int64

# %%
df3.groupby("Category")["Installs"].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME                  31544024415
# COMMUNICATION         24152276251
# SOCIAL                12513867902
# PRODUCTIVITY          12463091369
# TOOLS                 11452771915
# FAMILY                10041692505
# PHOTOGRAPHY            9721247655
# TRAVEL_AND_LOCAL       6361887146
# VIDEO_PLAYERS          6222002720
# NEWS_AND_MAGAZINES     5393217760
# Name: Installs, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(df3["Rating"], shade=True, color="r")
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df3["Rating"].mean()
# Out:
# 4.227425661243321

# %%
df3['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8382
# Teen               1146
# Mature 17+          447
# Everyone 10+        377
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
# Plot top five paid apps
plt.figure(figsize=(10,5))
df3[df3["Type"] == "Paid"].sort_values("Price", ascending=False).head(5).plot(x="App", y="Price", kind="bar")
# Out:
# <Axes: xlabel='App'>

# %%
# Plot top five paid apps
plt.figure(figsize=(10,5))
df3[df3["Type"] == "Free"].sort_values("Price", ascending=False).head(5).plot(x="App", y="Rating", kind="bar")
# Out:
# <Axes: xlabel='App'>
