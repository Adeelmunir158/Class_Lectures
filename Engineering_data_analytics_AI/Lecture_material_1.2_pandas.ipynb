# %% [markdown]
# # Pandas library
# # Pandas(Panel Data)
# The name "Pandas" is derived from the term "Panel Data," which is an econometrics term for multidimensional structured data sets.
# The library was originally developed by Wes McKinney in 2008 while working at Capital Management, primarily for data manipulation and analysis tasks in finance.\
#
# The name "Pandas" reflects the library's focus on providing data structures and functions that are particularly well-suited for working with structured data, including data manipulation, cleaning, and analysis.\
#
#  The library has become widely popular in the data science and analytics community for its ease of use and flexibility in handling tabular data, time-series data, and more.

# %%
import seaborn as sns
import pandas as pd
dir(pd) # to see the functions of pandas
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
#  '_pandas_datetime_CAPI',
#  '_pandas_parser_CAPI',
#  '_testing',
#  '_typing',
#  '_version_meson',
#  'annotations',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'from_dummies',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# importing data from clipboard
df = pd.read_clipboard()
df
# Out:
# Empty DataFrame
# Columns: [df.groupby(['class',, 'sex',, 'class']).size()]
# Index: []

# %%
import pandas as pd
df_excel = pd.read_excel("D:/Drive D/One drive folder/OneDrive - Higher Education Commission/Drive G/Data science coding/Data sets/Sample_Superstore.xlsx", sheet_name="Orders") # sheet_name=0 is default you can also change the sheet name = "Sheet1"
df_excel
# Out:
#         A`        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     4962  CA-2016-156587 2016-03-07 2016-03-08     First Class    AB-10015
# 1     4963  CA-2016-156587 2016-03-07 2016-03-08     First Class    AB-10015
# 2     4964  CA-2016-156587 2016-03-07 2016-03-08     First Class    AB-10015
# 3     8223  CA-2016-152905 2016-02-18 2016-02-24  Standard Class    AB-10015
# 4     8802  CA-2018-140935 2018-11-10 2018-11-12     First Class    AB-10015
# ...    ...             ...        ...        ...             ...         ...
# 9989  3815  CA-2018-152471 2018-07-08 2018-07-08        Same Day    ZD-21925
# 9990  3816  CA-2018-152471 2018-07-08 2018-07-08        Same Day    ZD-21925
# 9991  5898  CA-2018-167682 2018-04-03 2018-04-09  Standard Class    ZD-21925
# 9992  5899  CA-2018-167682 2018-04-03 2018-04-09  Standard Class    ZD-21925
# 9993  8342  CA-2019-141481 2019-06-11 2019-06-14     First Class    ZD-21925
#
#            Customer Name   Segment Country/Region           City  ...  \
# 0          Aaron Bergman  Consumer  United States        Seattle  ...
# 1          Aaron Bergman  Consumer  United States        Seattle  ...
# 2          Aaron Bergman  Consumer  United States        Seattle  ...
# 3          Aaron Bergman  Consumer  United States      Arlington  ...
# 4          Aaron Bergman  Consumer  United States  Oklahoma City  ...
# ...                  ...       ...            ...            ...  ...
# 9989  Zuschuss Donatelli  Consumer  United States   Jacksonville  ...
# 9990  Zuschuss Donatelli  Consumer  United States   Jacksonville  ...
# 9991  Zuschuss Donatelli  Consumer  United States       Richmond  ...
# 9992  Zuschuss Donatelli  Consumer  United States       Richmond  ...
# 9993  Zuschuss Donatelli  Consumer  United States    Los Angeles  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 0        98103.0     West  FUR-CH-10004477        Furniture       Chairs
# 1        98103.0     West  OFF-AR-10001427  Office Supplies          Art
# 2        98103.0     West  OFF-ST-10002344  Office Supplies      Storage
# 3        76017.0  Central  OFF-ST-10000321  Office Supplies      Storage
# 4        73120.0  Central  TEC-PH-10000562       Technology       Phones
# ...          ...      ...              ...              ...          ...
# 9989     32216.0    South  TEC-PH-10002824       Technology       Phones
# 9990     32216.0    South  OFF-PA-10004965  Office Supplies        Paper
# 9991     47374.0  Central  FUR-FU-10003799        Furniture  Furnishings
# 9992     47374.0  Central  TEC-PH-10000673       Technology       Phones
# 9993     90036.0     West  OFF-AP-10004532  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 0            Global Push Button Manager's Chair, Indigo   48.712         1
# 1                                            Newell 330   17.940         3
# 2               Carina 42"Hx23 3/4"W Media Storage Unit  242.940         3
# 3                                    Akro Stacking Bins   12.624         2
# 4                                      Samsung Convoy 3  221.980         2
# ...                                                 ...      ...       ...
# 9989           Jabra SPEAK 410 Multidevice Speakerphone  823.960         5
# 9990                                         Xerox 1921   15.984         2
# 9991                     Seth Thomas 13 1/2" Wall Clock   71.120         4
# 9992     Plantronics Voyager Pro HD - Bluetooth Headset  259.960         4
# 9993  Kensington 6 Outlet Guardian Standard Surge Pr...   61.440         3
#
#       Discount    Profit
# 0          0.2    5.4801
# 1          0.0    4.6644
# 2          0.0    4.8588
# 3          0.2   -2.5248
# 4          0.0   62.1544
# ...        ...       ...
# 9989       0.2   51.4975
# 9990       0.2    4.9950
# 9991       0.0   22.0472
# 9992       0.0  124.7808
# 9993       0.0   16.5888
#
# [9994 rows x 21 columns]

# %%
# load csv data
df_csv = pd.read_csv('D:\Drive D\One drive folder\OneDrive - Higher Education Commission\Drive G\Data science coding\Data sets\iris.csv')
df_csv
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# create a dataframe from a dictionary for the people ages and names
data = {'Name': ['Muhammad', 'Ali', 'Ahmad', 'Minahil'],
        'Age': [28, 23, 25, 27],
        'Weight': [70, 75, 80, 65]
        }
data
df = pd.DataFrame(data)
df
# Out:
#        Name  Age  Weight
# 0  Muhammad   28      70
# 1       Ali   23      75
# 2     Ahmad   25      80
# 3   Minahil   27      65

# %%
# df.to_clipboard()
# df.to_excel('../00_datasets/people.xlsx', index=False)
# df.to_csv('../00_datasets/people.csv', index=False)

# %%
# Reading Tabluar Data
df_tabulated = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')
df_tabulated
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
#Json file reading
df_json = pd.read_json('https://jsonplaceholder.typicode.com/posts')
df_json
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# 1   est rerum tempore vitae\nsequi sint nihil repr...
# 2   et iusto sed quo iure\nvoluptatem occaecati om...
# 3   ullam et saepe reiciendis voluptatem adipisci\...
# 4   repudiandae veniam quaerat sunt sed\nalias aut...
# ..                                                ...
# 95  in non odio excepturi sint eum\nlabore volupta...
# 96  eum non blanditiis soluta porro quibusdam volu...
# 97  doloremque ex facilis sit sint culpa\nsoluta a...
# 98  quo deleniti praesentium dicta non quod\naut e...
# 99  cupiditate quo est a modi nesciunt soluta\nips...
#
# [100 rows x 4 columns]

# %%
import pandas as pd

# Sample data with large financial values
financial_data = {
    'Company': ['Company A', 'Company B', 'Company C'],
    'Revenue': [123456789, 987654321.34, 56473829100000000],
    'Profit': [23456789, 876543211500000, 34738291.678]
}
fd = pd.DataFrame(financial_data)
fd.head()
# Out:
#      Company       Revenue        Profit
# 0  Company A  1.234568e+08  2.345679e+07
# 1  Company B  9.876543e+08  8.765432e+14
# 2  Company C  5.647383e+16  3.473829e+07

# %%
# display the numbers without scientific notation
pd.options.display.float_format = '{:,.2f}'.format
fd
# Out:
#      Company                   Revenue                 Profit
# 0  Company A            123,456,789.00          23,456,789.00
# 1  Company B            987,654,321.34 876,543,211,500,000.00
# 2  Company C 56,473,829,100,000,000.00          34,738,291.68

# %%
# display the numbers with scientific notation again
# pd.options.display.float_format = None
# fd

# %% [markdown]
# # Step-2: Formatting with Apply and Lambda
#
# We can use apply with lambda to format large numbers with commas for thousands, allowing more control over the displayed format.
#
# **Breakdown:**
#
# lambda x: Defines an anonymous function with a single argument x, which represents each value in the Profit column.\
# f'{x:,.0f}': Formats x as a string with commas separating thousands, millions, etc., and 0f to show no decimal places.\
# For instance, if x is 123456789, the lambda function converts it to "123,456,789".

# %%
# Format columns with commas
df_solution = fd.copy()

# %%
df_solution['Revenue'] = df_solution['Revenue'].apply(lambda x: f'{x:,.0f}') # f-string formatting with commas 
df_solution['Profit'] = df_solution['Profit'].apply(lambda x: f'{x:,.0f}') # f-string formatting with commas

df_solution
# Out:
#      Company                 Revenue               Profit
# 0  Company A             123,456,789           23,456,789
# 1  Company B             987,654,321  876,543,211,500,000
# 2  Company C  56,473,829,100,000,000           34,738,292

# %%
# to reset the options
pd.reset_option('display.float_format')
fd
# Out:
#      Company       Revenue        Profit
# 0  Company A  1.234568e+08  2.345679e+07
# 1  Company B  9.876543e+08  8.765432e+14
# 2  Company C  5.647383e+16  3.473829e+07

# %%
# import data of titanic
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Import data from file
#df=pd.read_csv('titanic.csv')

# %%
df=titanic.copy()

# %%
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [784 rows x 15 columns]

# %%
df.groupby('class').size()
# Out:
# C:\Users\adeel\AppData\Local\Temp\ipykernel_22040\1820622143.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('class').size()
# class
# First     216
# Second    184
# Third     491
# dtype: int64

# %%
df.groupby(['class', 'sex', 'class']).size()
# Out:
# C:\Users\adeel\AppData\Local\Temp\ipykernel_22040\1152377662.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['class', 'sex', 'class']).size()
# class   sex     class
# First   female  First      94
#                 Second      0
#                 Third       0
#         male    First     122
#                 Second      0
#                 Third       0
# Second  female  First       0
#                 Second     76
#                 Third       0
#         male    First       0
#                 Second    108
#                 Third       0
# Third   female  First       0
#                 Second      0
#                 Third     144
#         male    First       0
#                 Second      0
#                 Third     347
# dtype: int64

# %%
df.rename(columns={'sex': 'gender'}, inplace=True)
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   gender       891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# gender           object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
len(df)
# Out:
# 891

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# gender           0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum() / len(df) * 100 # percentage of missing values in a column
# Out:
# survived        0.000000
# pclass          0.000000
# gender          0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.isnull()
# Out:
#      survived  pclass  gender    age  sibsp  parch   fare  embarked  class  \
# 0       False   False   False  False  False  False  False     False  False
# 1       False   False   False  False  False  False  False     False  False
# 2       False   False   False  False  False  False  False     False  False
# 3       False   False   False  False  False  False  False     False  False
# 4       False   False   False  False  False  False  False     False  False
# ..        ...     ...     ...    ...    ...    ...    ...       ...    ...
# 886     False   False   False  False  False  False  False     False  False
# 887     False   False   False  False  False  False  False     False  False
# 888     False   False   False   True  False  False  False     False  False
# 889     False   False   False  False  False  False  False     False  False
# 890     False   False   False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# 0    False       False   True        False  False  False
# 1    False       False  False        False  False  False
# 2    False       False   True        False  False  False
# 3    False       False  False        False  False  False
# 4    False       False   True        False  False  False
# ..     ...         ...    ...          ...    ...    ...
# 886  False       False   True        False  False  False
# 887  False       False  False        False  False  False
# 888  False       False   True        False  False  False
# 889  False       False  False        False  False  False
# 890  False       False   True        False  False  False
#
# [891 rows x 15 columns]

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['gender'] # to select one column by name
df[['gender', 'age']] # to select two columns
df[['gender', 'age', 'fare']] # to select more than 2 column
# Out:
#      gender   age     fare
# 0      male  22.0   7.2500
# 1    female  38.0  71.2833
# 2    female  26.0   7.9250
# 3    female  35.0  53.1000
# 4      male  35.0   8.0500
# ..      ...   ...      ...
# 886    male  27.0  13.0000
# 887  female  19.0  30.0000
# 888  female   NaN  23.4500
# 889    male  26.0  30.0000
# 890    male  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
df['gender'].unique() # uniques values in a column
df.gender.nunique() # find number of unique values
# Out:
# 2

# %%
df.nunique() # to find number of unique values in all columns
# Out:
# survived         2
# pclass           3
# gender           2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.columns # to print the column names
# Out:
# Index(['survived', 'pclass', 'gender', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
# value count
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
# Summary
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # USE of LOC and ILOC function

# %%
# use of loc function
df.loc[0:5, 'gender':'fare']
# Out:
#    gender   age  sibsp  parch     fare
# 0    male  22.0      1      0   7.2500
# 1  female  38.0      1      0  71.2833
# 2  female  26.0      0      0   7.9250
# 3  female  35.0      1      0  53.1000
# 4    male  35.0      0      0   8.0500
# 5    male   NaN      0      0   8.4583

# %%
df.loc[0:15, 'fare':'deck']
# Out:
#        fare embarked   class    who  adult_male deck
# 0    7.2500        S   Third    man        True  NaN
# 1   71.2833        C   First  woman       False    C
# 2    7.9250        S   Third  woman       False  NaN
# 3   53.1000        S   First  woman       False    C
# 4    8.0500        S   Third    man        True  NaN
# 5    8.4583        Q   Third    man        True  NaN
# 6   51.8625        S   First    man        True    E
# 7   21.0750        S   Third  child       False  NaN
# 8   11.1333        S   Third  woman       False  NaN
# 9   30.0708        C  Second  child       False  NaN
# 10  16.7000        S   Third  child       False    G
# 11  26.5500        S   First  woman       False    C
# 12   8.0500        S   Third    man        True  NaN
# 13  31.2750        S   Third    man        True  NaN
# 14   7.8542        S   Third  child       False  NaN
# 15  16.0000        S  Second  woman       False  NaN

# %%
# using iloc function
df.iloc[0:5, 0:3]
# Out:
#    survived  pclass  gender
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
# 3         1       1  female
# 4         0       3    male

# %%
# find mean fars of both males and females using groubpy function
df.groupby(['survived', 'who']).size()
# Out:
# survived  who
# 0         child     34
#           man      449
#           woman     66
# 1         child     49
#           man       88
#           woman    205
# dtype: int64

# %%
# correlation matrix
correlation_df = df[['fare', 'age', 'sibsp', 'parch']].corr()

# %%
sns.heatmap(correlation_df, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# # Handle missing values

# %%
# find out the percentage of missing values
df.isnull().sum() / len(df) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# gender          0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# gender           0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#1- drop the column having more than 70% of missing values from dataset
df.drop('deck', axis=1, inplace=True)

# %%
df['age'].mean()
# Out:
# 29.69911764705882

# %%
df['age'].median()
# Out:
# 28.0

# %%
df['age'].mode()
# Out:
# 0    24.0
# Name: age, dtype: float64

# %%
# 2- filling missing values of age column by the mean of age
df['age'].fillna(df['age'].mean(), inplace=True)
# Out:
# C:\Users\adeel\AppData\Local\Temp\ipykernel_22040\974154890.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)

# %%
df['age'].fillna(df['age'].median(), inplace=True)
# Out:
# C:\Users\adeel\AppData\Local\Temp\ipykernel_22040\1654433547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# gender         0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
# fill embark and embarked_town with mode
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\adeel\AppData\Local\Temp\ipykernel_22040\2047704176.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %%
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df["embark_town"].fillna(df["embark_town"].mode()[0], inplace=True)
# Out:
# C:\Users\adeel\AppData\Local\Temp\ipykernel_22040\1592829824.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["embark_town"].fillna(df["embark_town"].mode()[0], inplace=True)

# %%
df.age.min()
# Out:
# 0.42

# %%
df.age.max()
# Out:
# 80.0

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# binning of age column into 7 categories
bins = [0,1,5,12,18,30,50,80]
labels = ['Infants', 'Toddlers', 'Kids', 'Teens', 'Youngs', 'Middle Aged', 'Old']

# %%
pd.cut(df['age'], bins=bins, labels=labels)
# Out:
# 0           Youngs
# 1      Middle Aged
# 2           Youngs
# 3      Middle Aged
# 4      Middle Aged
#           ...
# 886         Youngs
# 887         Youngs
# 888         Youngs
# 889         Youngs
# 890    Middle Aged
# Name: age, Length: 891, dtype: category
# Categories (7, object): ['Infants' < 'Toddlers' < 'Kids' < 'Teens' < 'Youngs' < 'Middle Aged' < 'Old']

# %%
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# # Feature engineering

# %%
bins = [0,1,5,12,18,30,50,80]
labels = ['Infants', 'Toddlers', 'Kids', 'Teens', 'Youngs', 'Middle Aged', 'Old']
# kis column ko bins main convert karna hy

df['binned_age'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
df['binned_age'].value_counts()
# Out:
# binned_age
# Youngs         447
# Middle Aged    241
# Teens           70
# Old             64
# Toddlers        30
# Kids            25
# Infants         14
# Name: count, dtype: int64

# %% [markdown]
# # Data Filteration

# %%
df_01 = df[['survived','binned_age','fare','class']]

# %%
df_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   binned_age  891 non-null    category
#  2   fare        891 non-null    float64
#  3   class       891 non-null    category
# dtypes: category(2), float64(1), int64(1)
# memory usage: 16.3 KB

# %%
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
# filter the data based on rows criteria
df_first = df_01[df_01['class'] == 'First']
df_first
# Out:
#      survived   binned_age     fare  class
# 1           1  Middle Aged  71.2833  First
# 3           1  Middle Aged  53.1000  First
# 6           0          Old  51.8625  First
# 11          1          Old  26.5500  First
# 23          1       Youngs  35.5000  First
# ..        ...          ...      ...    ...
# 871         1  Middle Aged  52.5542  First
# 872         0  Middle Aged   5.0000  First
# 879         1          Old  83.1583  First
# 887         1       Youngs  30.0000  First
# 889         1       Youngs  30.0000  First
#
# [216 rows x 4 columns]

# %%
# lets select only those rows whihc have paid more than 200 Pounds
df_200 = df_01[df_01['fare'] > 200]
df_200
# Out:
#      survived   binned_age      fare  class
# 27          0       Youngs  263.0000  First
# 88          1       Youngs  263.0000  First
# 118         0       Youngs  247.5208  First
# 258         1  Middle Aged  512.3292  First
# 299         1  Middle Aged  247.5208  First
# 311         1        Teens  262.3750  First
# 341         1       Youngs  263.0000  First
# 377         0       Youngs  211.5000  First
# 380         1  Middle Aged  227.5250  First
# 438         0          Old  263.0000  First
# 527         0       Youngs  221.7792  First
# 557         0       Youngs  227.5250  First
# 679         1  Middle Aged  512.3292  First
# 689         1        Teens  211.3375  First
# 700         1        Teens  227.5250  First
# 716         1  Middle Aged  227.5250  First
# 730         1       Youngs  211.3375  First
# 737         1  Middle Aged  512.3292  First
# 742         1       Youngs  262.3750  First
# 779         1  Middle Aged  211.3375  First

# %%
df_200['class'].value_counts()
# Out:
# class
# First     20
# Second     0
# Third      0
# Name: count, dtype: int64

# %%
# how to add two filter
df_01[(df_01['fare'] > 70) & (df_01['class']=='First')].sort_values(by='fare')
# Out:
#      survived   binned_age      fare  class
# 540         1  Middle Aged   71.0000  First
# 745         0          Old   71.0000  First
# 1           1  Middle Aged   71.2833  First
# 366         1          Old   75.2500  First
# 218         1  Middle Aged   76.2917  First
# ..        ...          ...       ...    ...
# 438         0          Old  263.0000  First
# 27          0       Youngs  263.0000  First
# 679         1  Middle Aged  512.3292  First
# 258         1  Middle Aged  512.3292  First
# 737         1  Middle Aged  512.3292  First
#
# [100 rows x 4 columns]

# %%
# use or function for filteration
df_01[(df_01['fare'] > 70) | (df_01['class']=='First')].sort_values(by='fare')
# Out:
#      survived   binned_age      fare  class
# 633         0       Youngs    0.0000  First
# 263         0  Middle Aged    0.0000  First
# 822         0  Middle Aged    0.0000  First
# 815         0       Youngs    0.0000  First
# 806         0  Middle Aged    0.0000  First
# ..        ...          ...       ...    ...
# 341         1       Youngs  263.0000  First
# 438         0          Old  263.0000  First
# 737         1  Middle Aged  512.3292  First
# 258         1  Middle Aged  512.3292  First
# 679         1  Middle Aged  512.3292  First
#
# [221 rows x 4 columns]

# %%
# import titanic data from seaborn library
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.rename(columns={"sex": "gender"}, inplace=True)

# %%
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.plot(kind='scatter', x='age', y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# change colors using hex codes
df.plot(kind='scatter', x='age', y='fare', color = '#32a852')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df.plot(kind='scatter', x='age', y='fare', color = 'red')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
group=df.groupby('gender')['fare'].mean()
group
# Out:
# gender
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64
