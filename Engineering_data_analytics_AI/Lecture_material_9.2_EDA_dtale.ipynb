# %%
#%pip install dtale

# %%
import pandas as pd
import seaborn as sns
import dtale

# %%
df=sns.load_dataset('diamonds')
# Start dtale server
d = dtale.show(df)
d.open_browser()  # this will open the dtale interface in your default web browser

# %%
# Kill the browser session
#d.kill()
# Out:
# 2026-01-14 17:07:26,000 - INFO     - Executing shutdown...
# 2026-01-14 17:07:26,006 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
