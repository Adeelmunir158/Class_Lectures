# %%
#pip install ipykernal
#pip install numpy
#pip install scipy
#%pip install pandas
#%pip install seaborn
#%pip install matplotlib
#%pip install plotly
#%pip install nbformat
#pip install scikit-learn

# %% [markdown]
# # Operations in python

# %%
2+1  # Addition
# Out:
# 3

# %%
print(2-1)
# Out:
# 1

# %%
2-1
# Out:
# 1

# %%
5*3 # multiplication
# Out:
# 15

# %%
4/2 # division
# Out:
# 2.0

# %%
17%3 # Remainder
# Out:
# 2

# %%
7//2 #No float
# Out:
# 3

# %%
7/2
# Out:
# 3.5

# %%
3**4 # Power function
# Out:
# 81

# %%
3**2/2*4/3+5-3 # PEMDAS
# Out:
# 8.0

# %%
"We are learning python with adeel"
# Out:
# 'We are learning python with adeel'

# %% [markdown]
# # Float
# # Integer
# # String

# %% [markdown]
# ### Python

# %% [markdown]
# # Strings

# %%
x=5

# %%
print(x)
# Out:
# 5

# %%
x=10

# %%
string= "My name is hamza and i am from Lahore"

# %%
string
# Out:
# 'My name is hamza and i am from Lahore'

# %%
x=2
y=4
x+y
print("The sum of x and y is: 6")
# Out:
# The sum of x and y is: 6

# %% [markdown]
# f string

# %%
string=(f"My name is adeel and i am from lahore")
string
# Out:
# 'My name is adeel and i am from lahore'

# %%
price=50.523696
print(f"The price of the product is: {price:.3f}")
# Out:
# The price of the product is: 50.524

# %% [markdown]
# # List
# # Tuples
# # Dictionary

# %% [markdown]
# Ordered collection of elements\
# Enclosed in []\
# Mutable\
# Allow duplicates

# %%
list1=[2,5,63,25,21,33,65,9,89,8,25]
list1
# Out:
# [2, 5, 63, 25, 21, 33, 65, 9, 89, 8, 25]

# %%
list2=["apple", "bannana", "orange", 20.5, True, 15]
list2
# Out:
# ['apple', 'bannana', 'orange', 20.5, True, 15]

# %%
list1.sort(reverse=True)

# %%
list1
# Out:
# [89, 65, 63, 33, 25, 25, 21, 9, 8, 5, 2]

# %%
list1*3
# Out:
# [89,
#  65,
#  63,
#  33,
#  25,
#  25,
#  21,
#  9,
#  8,
#  5,
#  2,
#  89,
#  65,
#  63,
#  33,
#  25,
#  25,
#  21,
#  9,
#  8,
#  5,
#  2,
#  89,
#  65,
#  63,
#  33,
#  25,
#  25,
#  21,
#  9,
#  8,
#  5,
#  2]

# %%
list1.insert(5,"B")

# %%
list1.remove("B")

# %%
list1
# Out:
# [89, 65, 63, 33, 25, 25, 21, 9, 8, 5, 2, 'B']

# %% [markdown]
# # Indexing and Slicing

# %%
a="Pakistan"

# %%
print(a[:4])
# Out:
# Paki

# %%
list1=[1,2,3]
list2=[4,5,5]

# %%
list1+list2
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
# Dictionaries

# %%
{}

# %%
dic={"a":25, "b":50, "c":75}

# %%
dic.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
dic.values()
# Out:
# dict_values([25, 50, 75])

# %%
dic2={"name":"Adeel", "age":25, "city":"Lahore"}
dic2
# Out:
# {'name': 'Adeel', 'age': 25, 'city': 'Lahore'}
