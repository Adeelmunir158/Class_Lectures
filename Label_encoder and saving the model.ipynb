# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
X=df.drop('sex',axis=1)
X
# Out:
#      total_bill   tip  smoker  day  time  size
# 0         16.99  1.01       0    2     0     2
# 1         10.34  1.66       0    2     0     3
# 2         21.01  3.50       0    2     0     3
# 3         23.68  3.31       0    2     0     2
# 4         24.59  3.61       0    2     0     4
# ..          ...   ...     ...  ...   ...   ...
# 239       29.03  5.92       0    1     0     3
# 240       27.18  2.00       1    1     0     2
# 241       22.67  2.00       1    1     0     2
# 242       17.82  1.75       0    1     0     2
# 243       18.78  3.00       0    3     0     2
#
# [244 rows x 6 columns]

# %%
y=df['sex']

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(df['smoker'])
df['smoker']=le.transform(df['smoker'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(df['day'])
df['day']=le.transform(df['day'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(df['smoker'])
df['smoker']=le.transform(df['smoker'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(df['time'])
df['time']=le.transform(df['time'])

# %%
df.head()
# Out:
#    total_bill   tip     sex  smoker  day  time  size
# 0       16.99  1.01  Female       0    2     0     2
# 1       10.34  1.66    Male       0    2     0     3
# 2       21.01  3.50    Male       0    2     0     3
# 3       23.68  3.31    Male       0    2     0     2
# 4       24.59  3.61  Female       0    2     0     4

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
# save the model
import joblib
joblib.dump(model,'tips_model')
# Out:
# ['tips_model']

# %%
# Load the model
model=joblib.load('tips_model')

# %%
# Save the model in pickle format
import pickle
pickle.dump(model,open('tips_model.pkl','wb'))

# %%
# Load the model
model=pickle.load(open('tips_model.pkl','rb'))
