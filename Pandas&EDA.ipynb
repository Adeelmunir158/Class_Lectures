# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('sub-division_population_of_pakistan.csv')
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# df.to_excel('sub-division_population_of_pakistan.xlsx', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
df.dtypes
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
df.groupby('MALE (RURAL)').sum()
# Out:
#                                                        PROVINCE  \
# MALE (RURAL)
# 0             PUNJABPUNJABPUNJABPUNJABPUNJABPUNJABSINDHSINDH...
# 1441                                                BALOCHISTAN
# 1447                                                   KPK/FATA
# 2645                                                BALOCHISTAN
# 3112                                                BALOCHISTAN
# ...                                                         ...
# 636150                                                   PUNJAB
# 651051                                                   PUNJAB
# 711866                                                   PUNJAB
# 730729                                                   PUNJAB
# 1172995                                                     KPK
#
#                                                        DIVISION  \
# MALE (RURAL)
# 0             BAHAWALPUR DIVISIONLAHORE DIVISIONLAHORE DIVIS...
# ...

# %%
df1=sns.load_dataset("titanic")
df1.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df1.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %%
df1["sex"] # to selct one column
df1[["sex","pclass"]]  # to select multiple columns
# Out:
#         sex  pclass
# 0      male       3
# 1    female       1
# 2    female       3
# 3    female       1
# 4      male       3
# ..      ...     ...
# 886    male       2
# 887  female       1
# 888  female       3
# 889    male       1
# 890    male       3
#
# [891 rows x 2 columns]

# %%
print(df1["sex"].unique())
df1.sex.nunique()
# Out:
# ['male' 'female']
# 2

# %%
df1.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df1["embark_town"].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df1["embark_town"].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df1.value_counts()
# Out:
# survived  pclass  sex     age   sibsp  parch  fare      embarked  class  who    adult_male  deck  embark_town  alive  alone
# 1         1       female  24.0  0      0      69.3000   C         First  woman  False       B     Cherbourg    yes    True     2
#                           58.0  0      0      26.5500   S         First  woman  False       C     Southampton  yes    True     1
#                           49.0  0      0      25.9292   S         First  woman  False       D     Southampton  yes    True     1
#                                 1      0      76.7292   C         First  woman  False       D     Cherbourg    yes    False    1
#                           50.0  0      1      247.5208  C         First  woman  False       B     Cherbourg    yes    False    1
#                                                                                                                               ..
# ...

# %%
df1.groupby("sex")["fare"].mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
df1.groupby("survived")["fare"].mean()
# Out:
# survived
# 0    22.117887
# 1    48.395408
# Name: fare, dtype: float64

# %%
df1.groupby(["survived","sex", "who"])["fare"].value_counts()
# Out:
# survived  sex     who    fare
# 0         female  child  31.2750     4
#                          27.9000     2
#                          21.0750     2
#                          7.8542      1
#                          151.5500    1
#                                     ..
# 1         male    man    18.7875     1
#                          15.7417     1
#                          13.8625     1
#                          8.6625      1
#                          8.1125      1
# Name: count, Length: 435, dtype: int64

# %%
df1[["fare","age","sibsp","parch"]].corr()
# Out:
#            fare       age     sibsp     parch
# fare   1.000000  0.096067  0.159651  0.216225
# age    0.096067  1.000000 -0.308247 -0.189119
# sibsp  0.159651 -0.308247  1.000000  0.414838
# parch  0.216225 -0.189119  0.414838  1.000000

# %%
sns.heatmap(df1[["fare","age","sibsp","parch"]].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df1)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df1.drop("deck", axis=1, inplace=True)

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
print(df1["age"].mean())
print(df1["age"].median())
print(df1["age"].mode()[0])
# Out:
# 29.69911764705882
# 29.69911764705882
# 29.69911764705882

# %%
# filling missing values if age by mean of age
df1["age"].fillna(df1["age"].mean(), inplace=True)

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df1["embark_town"].fillna(df1["embark_town"].mode()[0], inplace=True)

# %%
df1["embarked"].fillna(df1["embarked"].mode()[0], inplace=True)

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %%
df1.age.min()
# Out:
# 0.42

# %%
df1.age.max()
# Out:
# 80.0

# %%
sns.histplot(df1["age"])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Count'>

# %%
bins=[0,1,5,12,18,30,50,80]
labels=["infant","toddler","kids","teenager","young","adult","old"]

# %%
pd.cut(df1["age"], bins=bins, labels=labels)
# Out:
# 0      young
# 1      adult
# 2      young
# 3      adult
# 4      adult
#        ...
# 886    young
# 887    young
# 888    young
# 889    young
# 890    adult
# Name: age, Length: 891, dtype: category
# Categories (7, object): ['infant' < 'toddler' < 'kids' < 'teenager' < 'young' < 'adult' < 'old']

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df1["bined_age"]=pd.cut(df1["age"], bins=bins, labels=labels)
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone bined_age
# 0    man        True  Southampton    no  False     young
# 1  woman       False    Cherbourg   yes  False     adult
# 2  woman       False  Southampton   yes   True     young
# 3  woman       False  Southampton   yes  False     adult
# 4    man        True  Southampton    no   True     adult

# %%
df1["bined_age"].value_counts()
# Out:
# bined_age
# young       447
# adult       241
# teenager     70
# old          64
# toddler      30
# kids         25
# infant       14
# Name: count, dtype: int64

# %%
# Renaming the columns
df1.rename(columns={"bined_age":"age_category"}, inplace=True)

# %%
df1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'age_category'],
#       dtype='object')

# %%
df2=df1[["survived",'age_category','fare','class']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   survived      891 non-null    int64
#  1   age_category  891 non-null    category
#  2   fare          891 non-null    float64
#  3   class         891 non-null    category
# dtypes: category(2), float64(1), int64(1)
# memory usage: 16.3 KB

# %%
#filter the data
df_ist=df2[df2["class"]=="First"]
df_ist.head()
# Out:
#     survived age_category     fare  class
# 1          1        adult  71.2833  First
# 3          1        adult  53.1000  First
# 6          0          old  51.8625  First
# 11         1          old  26.5500  First
# 23         1        young  35.5000  First

# %%
df_second=df2[df2["fare"]>200]
df_second.head()
# Out:
#      survived age_category      fare  class
# 27          0        young  263.0000  First
# 88          1        young  263.0000  First
# 118         0        young  247.5208  First
# 258         1        adult  512.3292  First
# 299         1        adult  247.5208  First

# %%
df_second["class"].value_counts()
# Out:
# class
# First     20
# Second     0
# Third      0
# Name: count, dtype: int64

# %%
df_second=df2[df2["fare"]>50]
df_second["class"].value_counts()
# Out:
# class
# First     139
# Third      14
# Second      7
# Name: count, dtype: int64

# %%
# Double filter
df2[(df2["fare"]>50) & (df2["class"]=="First")]
# Out:
#      survived age_category      fare  class
# 1           1        adult   71.2833  First
# 3           1        adult   53.1000  First
# 6           0          old   51.8625  First
# 27          0        young  263.0000  First
# 31          1        young  146.5208  First
# ..        ...          ...       ...    ...
# 849         1        young   89.1042  First
# 856         1        adult  164.8667  First
# 867         0        adult   50.4958  First
# 871         1        adult   52.5542  First
# 879         1          old   83.1583  First
#
# [139 rows x 4 columns]

# %% [markdown]
# # Pakistan population analysis

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
df.dtypes
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
df.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
sns.boxplot(df, y="AREA (sq.km)")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: ylabel='AREA (sq.km)'>

# %%
sns.histplot(df, x="AREA (sq.km)")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='AREA (sq.km)', ylabel='Count'>

# %%
df.describe().transpose()
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %%
sns.boxplot(df, x="PROVINCE", y="ALL SEXES (RURAL)")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='PROVINCE', ylabel='ALL SEXES (RURAL)'>

# %%
sns.boxplot(df, x="DIVISION", y="ALL SEXES (RURAL)")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='DIVISION', ylabel='ALL SEXES (RURAL)'>

# %%
# IF IT IS VERY HARD TO PLOT THEN WE WILL USE GROUPBY FUNCTION
print(df["DISTRICT"].nunique())
df["DIVISION"].nunique()
# Out:
# 131
# 28

# %%
df.groupby("DIVISION").size().sort_values(ascending=False)
# Out:
# DIVISION
# Quetta Division                 38
# Makran Division                 37
# MALAKAND DIVISION               33
# Karachi Division                30
# Hyderabad Division              30
# RAWALPINDI DIVISION             22
# Larkana Division                21
# GUJRANWALA DIVISION             20
# Naseerabad Division             19
# Zhob Division                   19
# Kalat Division                  18
# Mirpurkhas Division             18
# Sukkur Division                 18
# PESHAWAR DIVISION               18
# LAHORE DIVISION                 17
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# Shaheed Benazirabad Division    15
# DERA ISMAIL KHAN DIVISION       15
# BANNU DIVISION                  15
# HAZARA DIVISION                 15
# BAHAWALPUR DIVISION             15
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# SAHIWAL DIVISION                 7
# ...

# %%
df.groupby("PROVINCE")["ALL SEXES (RURAL)"].mean()
# Out:
# PROVINCE
# BALOCHISTAN     67783.465649
# KPK            350603.380282
# KPK/FATA        99733.760870
# PUNJAB         480160.293706
# SINDH          167968.182482
# Name: ALL SEXES (RURAL), dtype: float64

# %%
df.groupby("DIVISION")["ALL SEXES (RURAL)"].sum()
# Out:
# DIVISION
# BAHAWALPUR DIVISION              8629763
# BANNU DIVISION                   2509303
# Badin Division                   1414614
# D.G.KHAN DIVISION                8603072
# DERA ISMAIL KHAN DIVISION        2352153
# FAISALABAD DIVISION              8955732
# GUJRANWALA DIVISION             10213964
# HAZARA DIVISION                  4751172
# Hyderabad Division               5283534
# KOHAT DIVISION                   2514548
# Kalat Division                   1093478
# Karachi Division                 1140492
# LAHORE DIVISION                  5932454
# Larkana Division                 4239907
# MALAKAND DIVISION                8356013
# MARDAN DIVISION                  3282690
# MULTAN DIVISION                  8851091
# Makran Division                  1576401
# Mirpurkhas Division              3414793
# Naseerabad Division              1335388
# PESHAWAR DIVISION                5714714
# Quetta Division                  3533122
# RAWALPINDI DIVISION              5872103
# ...

# %%
df.groupby("DIVISION")["ALL SEXES (URBAN)"].sum()
# Out:
# DIVISION
# BAHAWALPUR DIVISION              2822831
# BANNU DIVISION                    143564
# Badin Division                    390344
# D.G.KHAN DIVISION                1823775
# DERA ISMAIL KHAN DIVISION         407282
# FAISALABAD DIVISION              5229499
# GUJRANWALA DIVISION              5906897
# HAZARA DIVISION                   571983
# Hyderabad Division               3497322
# KOHAT DIVISION                    461559
# Kalat Division                    383152
# Karachi Division                14884402
# LAHORE DIVISION                 13457402
# Larkana Division                 1951019
# MALAKAND DIVISION                 965387
# MARDAN DIVISION                   716186
# MULTAN DIVISION                  3417082
# Makran Division                   932568
# Mirpurkhas Division               810152
# Naseerabad Division               325689
# PESHAWAR DIVISION                2478976
# Quetta Division                  1564608
# RAWALPINDI DIVISION              4134521
# ...

# %%
df.groupby(["PROVINCE","DIVISION","DISTRICT", "SUB DIVISION"])["ALL SEXES (URBAN)"].mean()
# Out:
# PROVINCE     DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                      0.0
#                                                                          JOHAN SUB-TEHSIL                     0.0
#                                                                          KALAT TEHSIL                     36796.0
#                                                                          MANGOCHAR TEHSIL                     0.0
#                                                                          SURAB TEHSIL                     35597.0
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                    0.0
#                                                                          KARAKH SUB-TEHSIL                    0.0
# ...

# %%
pd.set_option("display.max_rows", None)

# %%
df["ALL SEXES (RURAL)"].sum()
# Out:
# 130034790

# %%
print("The total rural population of Pakistan in 2017:",df["ALL SEXES (RURAL)"].sum())
# Out:
# The total rural population of Pakistan in 2017: 130034790

# %%
print("The total rural population of Pakistan in 1998:",df["POPULATION 1998 (RURAL)"].sum())
# Out:
# The total rural population of Pakistan in 1998: 88401981

# %%
change_in_population=(df["ALL SEXES (RURAL)"].sum())-(df["POPULATION 1998 (RURAL)"].sum())
change_in_population
# Out:
# 41632809
